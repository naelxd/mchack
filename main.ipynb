# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#                                client_id gender  birth_date create_date  \
# 0       fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 1       3012cabca5885ed53d348d6e57dab5de      М        1951  2009-09-24
# 2       d871ef96820b6c7a1ada8e01a772724e      Ж        1982  2006-12-25
# 3       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# 4       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# ...                                  ...    ...         ...         ...
# 371578  d69d3201104ab393c0638839a7284ad7      М        1953  2018-08-08
# 371579  a936fb30e2268d2874cdcaa221032915      М        1997  2022-05-12
# 371580  a9cf0bb4f06fa321704ced777e993b33      М        1983  2021-10-15
# 371581  f69eb17242ca85eb21349dc08220afb8      Ж        1986  2022-02-12
# 371582  93237191eddf8dec77cc947c3c086358      Ж        1959  2012-07-19
#
#        nonresident_flag  businessman_flag              city  term  \
# 0                     R                 0  Гусь-Хрустальный   NaN
# 1                     R                 0           Ишимбай   NaN
# 2                     R                 0              Юрга   NaN
# 3                     R                 0             Томск   NaN
# 4                     R                 0             Томск   NaN
# ...                 ...               ...               ...   ...
# 371578                R                 0         Пятигорск   NaN
# 371579                R                 0          Кемерово   NaN
# 371580                R                 0   Санкт-Петербург   NaN
# 371581                R                 0               Уфа   NaN
# 371582                R                 0            Москва   NaN
#
#         contract_sum                        product_category_name  ...  \
# 0                0.0  Договор на текущий счет для дебетовой карты  ...
# 1                0.0  Договор на текущий счет для дебетовой карты  ...
# 2                0.0  Договор на текущий счет для дебетовой карты  ...
# 3                0.0  Договор на текущий счет для дебетовой карты  ...
# 4                0.0  Договор на текущий счет для дебетовой карты  ...
# ...              ...                                          ...  ...
# 371578      200000.0                              Кредитная карта  ...
# 371579       15000.0                              Кредитная карта  ...
# 371580       15000.0                              Кредитная карта  ...
# 371581       15000.0                              Кредитная карта  ...
# 371582       30000.0                              Кредитная карта  ...
#
#                    card_type_name start_date  fact_close_date  purchase_sum  \
# 0           Visa Platinum Rewards     2019.0           2021.0       16600.0
# 1                    VISA Classic     2019.0              NaN           0.0
# 2                             NaN        NaN              NaN           0.0
# 3                    Visa Rewards     2021.0              NaN       24300.0
# 4       Eurocard/MasterCard World     2018.0           2022.0       24300.0
# ...                           ...        ...              ...           ...
# 371578                        NaN        NaN              NaN           0.0
# 371579                        NaN        NaN              NaN       15000.0
# 371580                        NaN        NaN              NaN         600.0
# 371581                        NaN        NaN              NaN           0.0
# 371582                        NaN        NaN              NaN        9900.0
#
#         purchase_count  current_balance_avg_sum  current_balance_sum  \
# 0                   71                  39700.0              25700.0
# 1                    0                   1900.0               1000.0
# 2                    0                      0.0                  0.0
# 3                  118                      0.0                  0.0
# 4                  118                      0.0                  0.0
# ...                ...                      ...                  ...
# 371578               0                      0.0                300.0
# 371579              33                      0.0                  0.0
# 371580               5                      0.0                  0.0
# 371581               0                      0.0                  0.0
# 371582              19                      0.0                  0.0
#
#         current_debit_turn_sum  current_credit_turn_sum  card_type
# 0                     220600.0                 201000.0         dc
# 1                       6200.0                   3000.0         dc
# 2                          0.0                      0.0         dc
# 3                      35400.0                  35400.0         cc
# 4                      35400.0                  35400.0         cc
# ...                        ...                      ...        ...
# 371578                  9900.0                  10100.0         dc
# 371579                 15000.0                  15000.0         dc
# 371580                  1100.0                   1100.0         dc
# 371581                  1100.0                   1100.0         dc
# 371582                 29900.0                  29900.0         dc
#
# [371583 rows x 21 columns]

# %%
new_data = data.copy().drop('client_id', axis=1)

# %%
new_data['client_age'] = 2022 - new_data['birth_date']

# %%
new_data['client_age'].mean()
# Out:
# 43.594631616624014

# %%
new_data[new_data['current_balance_avg_sum'] != 0]
# Out:
#        gender  birth_date create_date nonresident_flag  businessman_flag  \
# 0           Ж        1985  2020-01-29                R                 0
# 1           М        1951  2009-09-24                R                 0
# 5           Ж        1980  2015-06-19                R                 0
# 9           М        1989  2010-12-16                R                 0
# 10          М        1989  2010-12-16                R                 0
# ...       ...         ...         ...              ...               ...
# 371561      М        1990  2022-02-03                N                 0
# 371562      М        1976  2014-06-16                R                 0
# 371563      Ж        1990  2010-03-09                R                 0
# 371566      М        1970  2020-06-11                R                 0
# 371571      М        1977  2007-05-21                R                 0
#
#                     city  term  contract_sum  \
# 0       Гусь-Хрустальный   NaN           0.0
# 1                Ишимбай   NaN           0.0
# 5            Октябрьский   NaN           0.0
# 9                 Туапсе   NaN           0.0
# 10                Туапсе   NaN           0.0
# ...                  ...   ...           ...
# 371561            Москва   NaN           0.0
# 371562      Екатеринбург   NaN           0.0
# 371563              Сочи   NaN           0.0
# 371566               Уфа   NaN           0.0
# 371571              Ейск   NaN      500000.0
#
#                               product_category_name  \
# 0       Договор на текущий счет для дебетовой карты
# 1       Договор на текущий счет для дебетовой карты
# 5       Договор на текущий счет для дебетовой карты
# 9       Договор на текущий счет для дебетовой карты
# 10      Договор на текущий счет для дебетовой карты
# ...                                             ...
# 371561  Договор на текущий счет для дебетовой карты
# 371562  Договор на текущий счет для дебетовой карты
# 371563  Договор на текущий счет для дебетовой карты
# 371566  Договор на текущий счет для дебетовой карты
# 371571                              Кредитная карта
#
#                                  card_id  ... start_date  fact_close_date  \
# 0       a83cbc33f164deae41b3339141923cc7  ...     2019.0           2021.0
# 1       8dae17a830bb05d151034df618efbcad  ...     2019.0              NaN
# 5       e3baaf11e34b13c3cbb93fd6e2f6096e  ...     2019.0              NaN
# 9       ca3b0bab14de9b04132ecb84c2b01f6c  ...     2019.0              NaN
# 10      bae6632af4c6d36013a6a6a594a261d6  ...     2021.0              NaN
# ...                                  ...  ...        ...              ...
# 371561  ad3b2e642411178eb49102879d90ca42  ...     2022.0              NaN
# 371562  b1397fb53973dd0dfbebc904d62d4e12  ...     2021.0              NaN
# 371563  7e84d8c74dc6cf9ef92401134d3aa68b  ...     2021.0              NaN
# 371566  dccd72269a1b128a42c18e61f9f70cf6  ...     2022.0              NaN
# 371571  9416050372d690b3d48d435f6c84e193  ...        NaN              NaN
#
#         purchase_sum  purchase_count  current_balance_avg_sum  \
# 0            16600.0              71                  39700.0
# 1                0.0               0                   1900.0
# 5                0.0               0                  12700.0
# 9             9700.0              33                   6100.0
# 10            9700.0              33                   6100.0
# ...              ...             ...                      ...
# 371561         500.0               3                   1500.0
# 371562        1000.0               4                    100.0
# 371563           0.0               0                    100.0
# 371566           0.0               0                  15600.0
# 371571      179800.0               8                    100.0
#
#         current_balance_sum  current_debit_turn_sum  current_credit_turn_sum  \
# 0                   25700.0                220600.0                 201000.0
# 1                    1000.0                  6200.0                   3000.0
# 5                    1000.0                 15000.0                   7800.0
# 9                   10200.0                 13800.0                  23500.0
# 10                  10200.0                 13800.0                  23500.0
# ...                     ...                     ...                      ...
# 371561               6700.0                 12400.0                  12200.0
# 371562                  0.0                 30000.0                  30000.0
# 371563                100.0                     0.0                      0.0
# 371566              15600.0                     0.0                      0.0
# 371571                  0.0                240100.0                 239800.0
#
#         card_type client_age
# 0              dc         37
# 1              dc         71
# 5              dc         42
# 9              dc         33
# 10             dc         33
# ...           ...        ...
# 371561         dc         32
# 371562         dc         46
# 371563         dc         32
# 371566         dc         52
# 371571         dc         45
#
# [210431 rows x 21 columns]

# %%
(371583 - 210431) / 371583
# Out:
# 0.43369045408428264

# %%
new_data['city'].value_counts()
# Out:
# Уфа                 59076
# Москва              31072
# Краснодар           21470
# Санкт-Петербург     12982
# Стерлитамак         12454
#                     ...
# Березники             200
# Курганинск            197
# Ангарск               191
# Языково               131
# Николо-Березовка      102
# Name: city, Length: 150, dtype: int64
